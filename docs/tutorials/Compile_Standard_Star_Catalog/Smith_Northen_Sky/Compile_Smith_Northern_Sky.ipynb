# %%
import pandas as pd
import numpy as np
from pathlib import Path
from researchcodes import (
    define_column_desc, 
    iter_multi_csv_chunks, 
    write_std_h5, 
    count_lines_fast,
)

from tqdm.notebook import tqdm

# %%
# Download full Smith Extended Northern and Equatorial
# https://www-star.fnal.gov/NorthEqExtension_ugriz/index.html

# %% [markdown]
# # Process the text catalog

# %% [markdown]
# The magnitude errors need calculation, so it's better to process ahead of reading and writing.
#
# I also need to drop rows marked by "*" and replace -100 and 0 with `np.nan` as missing values

# %%
# list of all the raw data file
raw_file_list = list(
    Path("usno40stds.clean.v3").glob("*v3")
)
raw_file_list
# Out:
# [PosixPath('usno40stds.clean.v3/109_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+25o4655.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ross49.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/114_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Feige34.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Hilt760.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+26o2606.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/95_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/G163_50-51.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/PG1528+062B.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/113_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/G3-33.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GCRV9438.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/LHS-1858.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/101_c.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/114_c.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/112_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/107_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Hilt733.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+71o31.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ross374.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+33o2642.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/94_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/92_d.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ross838.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/100_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/115_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/G15-24.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/113_c.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+38o4955.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/PG1323-086D.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/108_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Hilt233.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Wolf1447.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/G14-55.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ross711.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/97_c.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/97_d.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ross34.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD-21o910.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GJ745AB.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Hilt566.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/110_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+44o1910.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/110_e.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Hilt404.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/96_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+28o4211.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+25o1981.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD-12o2918.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/97_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/PG2336+004B.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GCRV7951.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/111_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/96_c.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Wolf1346.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/110_d.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GCRV7017.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/98_b.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ru149.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ross106.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GD246.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/99_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GD71.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/96_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+33o4737.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/110_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/105_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+8o2015.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/104_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/111_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GCRV5951.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GCRV5757.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/97_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+18o3407.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/98_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Hilt190.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Hilt1089.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+75o325.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Wolf365.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/101_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Hilt31.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/LHS-0394.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ross530.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+21o607.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/PG1047+003A.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/109_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/92_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+2o3375.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Feige22.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/Ross683.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/G27-45.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+54o1216.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/113_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/95_f.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+17o4708.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+62o1916.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/GCRV8758.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/94_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD-11o5781.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/112_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/107_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/PG0918+029D.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+29o2091.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/93_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/108_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/LHS-0033.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/BD+9o2190.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/100_a.txt.clean.v3'),
#  PosixPath('usno40stds.clean.v3/115_a.txt.clean.v3')]

# %%
# create a folder to save the processed data file

process_file_dir = Path("Northern_ugriz_processed")
process_file_dir.mkdir(exist_ok=True)

# %%
all_column_names = [
    "id_name",
    "ra",
    "dec",
    "SDSS_up", "SDSS_up_rms_err", "SDSS_up_nobs",
    "SDSS_gp", "SDSS_gp_rms_err", "SDSS_gp_nobs",
    "SDSS_rp", "SDSS_rp_rms_err", "SDSS_rp_nobs",
    "SDSS_ip", "SDSS_ip_rms_err", "SDSS_ip_nobs",
    "SDSS_zp", "SDSS_zp_rms_err", "SDSS_zp_nobs",
]

pbar_files = tqdm(
    raw_file_list,
    desc="Files",
    total=len(raw_file_list),
    position=0,
    leave=True,
)

for file in pbar_files:

    pbar_files.set_postfix_str(file.name, refresh=True)

    field_name = file.stem.split(".")[0]

    raw_text_catalog = pd.read_csv(
        file,
        sep=r"\s+",
        engine="python",
        header=0,
        names=all_column_names,
    )

    # the columns need to check missing values
    missing_magnitude_columns = [
        "SDSS_up", "SDSS_up_rms_err",
        "SDSS_gp", "SDSS_gp_rms_err",
        "SDSS_rp", "SDSS_rp_rms_err",
        "SDSS_ip", "SDSS_ip_rms_err",
        "SDSS_zp", "SDSS_zp_rms_err",
    ]
    missing_nobs_columns = ["SDSS_up_nobs","SDSS_gp_nobs","SDSS_rp_nobs","SDSS_ip_nobs","SDSS_zp_nobs"]
    
    # replace all missing values (-100) by np.nan
    raw_text_catalog[missing_magnitude_columns] = raw_text_catalog[missing_magnitude_columns].replace(-100, np.nan)
    # replace all missing values (0) by np.nan
    raw_text_catalog[missing_nobs_columns] = raw_text_catalog[missing_nobs_columns].replace(0, np.nan)  

    # calculate the ra ande dec errors
    # this formula (rm/sqrt(Ntot)) is 
    # in the comments of the catalog file
    for b in ["up","gp","rp","ip","zp"]:
        raw_text_catalog[f"SDSS_{b}_err"] = raw_text_catalog[f"SDSS_{b}_rms_err"]/np.sqrt(raw_text_catalog[f"SDSS_{b}_nobs"])

    # drop the columns we don't want in the final output file
    process_text_catalog = raw_text_catalog.drop(
        columns=[
            "SDSS_up_rms_err", "SDSS_up_nobs",
            "SDSS_gp_rms_err", "SDSS_gp_nobs",
            "SDSS_rp_rms_err", "SDSS_rp_nobs",
            "SDSS_ip_rms_err", "SDSS_ip_nobs",
            "SDSS_zp_rms_err", "SDSS_zp_nobs",
        ]
    )


    # Adding the field name to the standard stars to make it unique
    new_name = [field_name + f"_{id_name}" for id_name in process_text_catalog["id_name"]]
    process_text_catalog["id_name"] = new_name
    
    process_text_catalog.to_csv(
        process_file_dir / f"{field_name}_processed.csv",
        sep=",",
        index=False,
    )
# Out:
# Files:   0%|          | 0/110 [00:00<?, ?it/s]

# %% [markdown]
# # Define the HFD5 column description

# %%
# Define magnitude column names

# Note this magnitude column order is not necessarily
# to be the same as the column order in the text file. 

# It is OK as long as the filter names in 
# `magnitude_column_names` matches `colnames` defined 
# when reading the text file

magnitude_column_names = [
     "SDSS_up","SDSS_gp","SDSS_rp","SDSS_ip","SDSS_zp",
    "SDSS_up_err","SDSS_gp_err","SDSS_rp_err","SDSS_ip_err","SDSS_zp_err",
]

# define h5 file column description
h5_columns = define_column_desc(
    magnitude_column_names=magnitude_column_names, 
    id_name_length=25, 
)

# %%
h5_columns
# Out:
# {'id_name': StringCol(itemsize=25, shape=(), dflt=np.bytes_(b''), pos=0),
#  'ra': Float32Col(shape=(), dflt=np.float32(0.0), pos=1),
#  'ra_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=2),
#  'dec': Float32Col(shape=(), dflt=np.float32(0.0), pos=3),
#  'dec_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=4),
#  'SDSS_up': Float32Col(shape=(), dflt=np.float32(0.0), pos=5),
#  'SDSS_gp': Float32Col(shape=(), dflt=np.float32(0.0), pos=6),
#  'SDSS_rp': Float32Col(shape=(), dflt=np.float32(0.0), pos=7),
#  'SDSS_ip': Float32Col(shape=(), dflt=np.float32(0.0), pos=8),
#  'SDSS_zp': Float32Col(shape=(), dflt=np.float32(0.0), pos=9),
#  'SDSS_up_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=10),
#  'SDSS_gp_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=11),
#  'SDSS_rp_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=12),
#  'SDSS_ip_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=13),
#  'SDSS_zp_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=14),
#  'ipix': Int32Col(shape=(), dflt=np.int32(0), pos=15),
#  'bucket': Int32Col(shape=(), dflt=np.int32(0), pos=16)}

# %% [markdown]
# # Read the cvs files

# %%
# file path
root_dir = Path("Northern_ugriz_processed")
files = list(root_dir.glob("*csv"))
files
# Out:
# [PosixPath('Northern_ugriz_processed/Hilt733_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ross530_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Wolf1447_processed.csv'),
#  PosixPath('Northern_ugriz_processed/97_d_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Hilt1089_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GD246_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ross106_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ross374_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+38o4955_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GCRV5951_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ross49_processed.csv'),
#  PosixPath('Northern_ugriz_processed/101_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+25o1981_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Hilt190_processed.csv'),
#  PosixPath('Northern_ugriz_processed/95_f_processed.csv'),
#  PosixPath('Northern_ugriz_processed/92_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/110_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/95_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/109_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+44o1910_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD-11o5781_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+25o4655_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+8o2015_processed.csv'),
#  PosixPath('Northern_ugriz_processed/110_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/109_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/110_e_processed.csv'),
#  PosixPath('Northern_ugriz_processed/97_c_processed.csv'),
#  PosixPath('Northern_ugriz_processed/111_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/LHS-0033_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GCRV9438_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+75o325_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+9o2190_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD-21o910_processed.csv'),
#  PosixPath('Northern_ugriz_processed/G15-24_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Hilt566_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+54o1216_processed.csv'),
#  PosixPath('Northern_ugriz_processed/108_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/94_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Feige34_processed.csv'),
#  PosixPath('Northern_ugriz_processed/G3-33_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ross711_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+29o2091_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Hilt760_processed.csv'),
#  PosixPath('Northern_ugriz_processed/107_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/113_c_processed.csv'),
#  PosixPath('Northern_ugriz_processed/100_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GCRV7017_processed.csv'),
#  PosixPath('Northern_ugriz_processed/96_c_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ross34_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+21o607_processed.csv'),
#  PosixPath('Northern_ugriz_processed/107_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/114_c_processed.csv'),
#  PosixPath('Northern_ugriz_processed/100_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/G27-45_processed.csv'),
#  PosixPath('Northern_ugriz_processed/93_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/111_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/PG1047+003A_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+2o3375_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ross838_processed.csv'),
#  PosixPath('Northern_ugriz_processed/94_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/108_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/114_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/96_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GCRV8758_processed.csv'),
#  PosixPath('Northern_ugriz_processed/113_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GCRV7951_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+17o4708_processed.csv'),
#  PosixPath('Northern_ugriz_processed/LHS-1858_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Wolf365_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+18o3407_processed.csv'),
#  PosixPath('Northern_ugriz_processed/105_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/99_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Feige22_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GCRV5757_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GD71_processed.csv'),
#  PosixPath('Northern_ugriz_processed/PG0918+029D_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+62o1916_processed.csv'),
#  PosixPath('Northern_ugriz_processed/LHS-0394_processed.csv'),
#  PosixPath('Northern_ugriz_processed/96_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/113_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/G163_50-51_processed.csv'),
#  PosixPath('Northern_ugriz_processed/110_d_processed.csv'),
#  PosixPath('Northern_ugriz_processed/PG1323-086D_processed.csv'),
#  PosixPath('Northern_ugriz_processed/PG1528+062B_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+33o2642_processed.csv'),
#  PosixPath('Northern_ugriz_processed/98_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD-12o2918_processed.csv'),
#  PosixPath('Northern_ugriz_processed/PG2336+004B_processed.csv'),
#  PosixPath('Northern_ugriz_processed/97_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/101_c_processed.csv'),
#  PosixPath('Northern_ugriz_processed/115_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+26o2606_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Wolf1346_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+71o31_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+28o4211_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Hilt404_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ross683_processed.csv'),
#  PosixPath('Northern_ugriz_processed/112_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/115_b_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Hilt31_processed.csv'),
#  PosixPath('Northern_ugriz_processed/97_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/GJ745AB_processed.csv'),
#  PosixPath('Northern_ugriz_processed/112_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/BD+33o4737_processed.csv'),
#  PosixPath('Northern_ugriz_processed/92_d_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Ru149_processed.csv'),
#  PosixPath('Northern_ugriz_processed/Hilt233_processed.csv'),
#  PosixPath('Northern_ugriz_processed/G14-55_processed.csv'),
#  PosixPath('Northern_ugriz_processed/104_a_processed.csv'),
#  PosixPath('Northern_ugriz_processed/98_a_processed.csv')]

# %%
# csv column names
colnames = [
    "id_name", "ra", "dec",
    "SDSS_up", "SDSS_gp","SDSS_rp", "SDSS_ip","SDSS_zp",
    "SDSS_up_err", "SDSS_gp_err", "SDSS_rp_err", "SDSS_ip_err", "SDSS_zp_err",
]

dataframe_iterator = iter_multi_csv_chunks(
    files=files, 
    chunksize=10, 
    read_csv_kwargs={
        "sep": ",", 
        "engine": "python", 
        "header":0,
    }
)

# %%
table_attrs = {
    "ra_unit": "deg",
    "dec_unit": "deg",
    "ra_err_unit": "arcsec",
    "dec_err_unit": "arcsec",
    "version": "10 September 2012 (v3)",
    "mag_system": {
        "SDSS_ugriz": "AB",
    },
}

# %%
write_std_h5(
    dataframe_iterator=dataframe_iterator, 
    ra_dec_hmsdms=True,
    h5_output_path=Path("Smith_Northern_Sky.h5",), 
    group_where="/smith", 
    group_name="northern", 
    group_title="Northern Sky", 
    table_name="std", 
    table_description=h5_columns, 
    table_title="Standard Stars", 
    table_attrs=table_attrs, 
    nside=512, 
    bucket_size=1536 , 
)
