# %%
from researchcodes import VIRTPointingReport
from pathlib import Path

# %% [markdown]
# # Glob the fits files to analyze

# %%
file_dir = Path(".").resolve()
file_dir
# Out:
# PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT')

# %%
files = list(file_dir.glob("*fts"))
files
# Out:
# [PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT/WASP-51-b_I_34.fts'),
#  PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT/M44_B_39.fts'),
#  PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT/M44_B_38.fts'),
#  PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT/WASP-51-b_I_48.fts'),
#  PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT/M44_B_36.fts'),
#  PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT/M44_B_37.fts'),
#  PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT/Crab-Nebula_I_98.fts'),
#  PosixPath('/Users/shengyong/Desktop/ResearchCodes/docs/tutorials/VIRT/M44_B_41.fts')]

# %% [markdown]
# # Start reporting

# %%
report = VIRTPointingReport(
    files=files,
    hdu_index=0,
)

# %% [markdown]
# ## Get all target corodinates

# %%
report.get_target_coordinates()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# ['08:15:48.000 +05:49:59.000',
#  '08:40:24.000 +19:40:59.000',
#  '05:34:31.000 +22:00:51.000']

# %% [markdown]
# ## Plot target on an all-sky map

# %%
# Note that the target name order must match the
# target coordinates order you obtained from lat step.

report.plot_all_targets_aitoff(
    target_names=["WASP-51-b", "M44", "Crab-Nebula"],
)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]

# %% [markdown]
# ## Get offset summary table

# %%
report.get_offset_form()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# | File             | Pointing                     | FOV Center                   | RA Error     | Dec Error    |   Separation[arcsec] |
# |------------------|------------------------------|------------------------------|--------------|--------------|----------------------|
# | WASP-51-b_I_34   | 08:15:48.0200 +05:49:59.1000 | 08:15:35.2396 +05:52:50.9373 | -0:00:12.713 | +0:02:51.846 |            0.0713064 |
# | M44_B_39         | 08:40:23.9600 +19:40:58.9000 | 08:40:24.2532 +19:42:04.3207 | +0:00:00.276 | +0:01:05.421 |            0.0182088 |
# | M44_B_38         | 08:40:24.0100 +19:40:59.0000 | 08:40:24.3702 +19:42:03.8566 | +0:00:00.339 | +0:01:04.857 |            0.0180711 |
# | WASP-51-b_I_48   | 08:15:47.9500 +05:49:59.0000 | 08:15:30.0117 +05:53:05.8281 | -0:00:17.844 | +0:03:06.846 |            0.0906728 |
# ...

# %% [markdown]
# ## Visualize the offsets

# %%
report.plot_pointing_offsets()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
