# %%
import matplotlib.pyplot as plt
import astropy.units as u
from astropy.coordinates import SkyCoord

# %% [markdown]
# # Set up source names and coordinates

# %%
skycoords = SkyCoord(
    ra=["05 34 31.78", "08 39 58.40"],
    dec=["+22 01 02.6", "+19 36 33.0"],
    unit=(u.hourangle, u.deg),
    frame="fk5",
)

names = ["Crab", "M44"]

# %%
coords = skycoords.galactic
lon = coords.l.wrap_at(180 * u.deg).radian
lat = coords.b.radian
xlabel = "Galactic Longitude"
ylabel = "Galactic Latitude"

# %% [markdown]
# # Plot the sources with their names

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection="aitoff")
ax.grid(True)

ax.scatter(lon, lat, s=40)

for x, y, name in zip(lon, lat, names):
    ax.annotate(
        name,
        xy=(x, y),
        xytext=(5, 5),
        textcoords="offset points",
        ha="left",
        va="bottom",
    )

ax.set_title("All-sky target map")
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
plt.tight_layout()
