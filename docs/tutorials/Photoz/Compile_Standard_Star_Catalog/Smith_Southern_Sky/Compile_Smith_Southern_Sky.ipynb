# %%
import pandas as pd
import numpy as np
from pathlib import Path
from researchcodes import (
    define_column_desc, 
    iter_multi_csv_chunks, 
    write_std_h5, 
    count_lines_fast,
)

from tqdm.notebook import tqdm

# %%
# Download full Smith Southern Standard Stars
# https://www-star.fnal.gov/Southern_ugriz/New/index.html

# %% [markdown]
# # Process the text catalog

# %% [markdown]
# The magnitude errors need calculation, so it's better to process ahead of reading and writing.
#
# I also need to drop rows marked by "*" and replace -100 and 0 with `np.nan` as missing values

# %%
# list of all the raw data file
raw_file_list = list(
    Path("Southern_ugriz_trimmed").glob("*trimmed")
)

# %%
# create a folder to save the processed data file

process_file_dir = Path("Southern_ugriz_processed")
process_file_dir.mkdir(exist_ok=True)

# %%
all_column_names = [
    "id_name",
    "ra",
    "dec",
    "SDSS_up", "SDSS_up_rms_err", "SDSS_up_nobs",
    "SDSS_gp", "SDSS_gp_rms_err", "SDSS_gp_nobs",
    "SDSS_rp", "SDSS_rp_rms_err", "SDSS_rp_nobs",
    "SDSS_ip", "SDSS_ip_rms_err", "SDSS_ip_nobs",
    "SDSS_zp", "SDSS_zp_rms_err", "SDSS_zp_nobs",
    "nearest", "nearest_aper", "asterisk",
]

pbar_files = tqdm(
    raw_file_list,
    desc="Files",
    total=len(raw_file_list),
    position=0,
    leave=True,
)

for file in pbar_files:

    pbar_files.set_postfix_str(file.name, refresh=True)

    field_name = file.stem.split(".")[0]

    raw_text_catalog = pd.read_csv(
        file,
        sep=r"\s+",
        engine="python",
        header=None,
        names=all_column_names,
        comment="#",      # 直接跳过所有 ### 开头的说明行
    )

    # drop the entire row if there is a asterisk for the row 
    raw_text_catalog.drop(
        raw_text_catalog[raw_text_catalog["asterisk"]=="*"].index,
        inplace=True,
    )

    # the columns need to check missing values
    missing_magnitude_columns = [
        "SDSS_up", "SDSS_up_rms_err",
        "SDSS_gp", "SDSS_gp_rms_err",
        "SDSS_rp", "SDSS_rp_rms_err",
        "SDSS_ip", "SDSS_ip_rms_err",
        "SDSS_zp", "SDSS_zp_rms_err",
    ]
    missing_nobs_columns = ["SDSS_up_nobs","SDSS_gp_nobs","SDSS_rp_nobs","SDSS_ip_nobs","SDSS_zp_nobs"]
    
    # replace all missing values (-100) by np.nan
    raw_text_catalog[missing_magnitude_columns] = raw_text_catalog[missing_magnitude_columns].replace(-100, np.nan)
    # replace all missing values (0) by np.nan
    raw_text_catalog[missing_nobs_columns] = raw_text_catalog[missing_nobs_columns].replace(0, np.nan)  

    # calculate the ra ande dec errors
    # this formula (rm/sqrt(Ntot)) is 
    # in the comments of the catalog file
    for b in ["up","gp","rp","ip","zp"]:
        raw_text_catalog[f"SDSS_{b}_err"] = raw_text_catalog[f"SDSS_{b}_rms_err"]/np.sqrt(raw_text_catalog[f"SDSS_{b}_nobs"])

    # drop the columns we don't want in the final output file
    process_text_catalog = raw_text_catalog.drop(
        columns=[
            "SDSS_up_rms_err", "SDSS_up_nobs",
            "SDSS_gp_rms_err", "SDSS_gp_nobs",
            "SDSS_rp_rms_err", "SDSS_rp_nobs",
            "SDSS_ip_rms_err", "SDSS_ip_nobs",
            "SDSS_zp_rms_err", "SDSS_zp_nobs",
            "nearest", "nearest_aper", "asterisk",
        ]
    )

    process_text_catalog.to_csv(
        process_file_dir / f"{field_name}_processed.csv",
        sep=",",
        index=False,
    )
# Out:
# Files:   0%|          | 0/58 [00:00<?, ?it/s]

# %% [markdown]
# # Define the HFD5 column description

# %%
# Define magnitude column names

# Note this magnitude column order is not necessarily
# to be the same as the column order in the text file. 

# It is OK as long as the filter names in 
# `magnitude_column_names` matches `colnames` defined 
# when reading the text file

magnitude_column_names = [
     "SDSS_up","SDSS_gp","SDSS_rp","SDSS_ip","SDSS_zp",
    "SDSS_up_err","SDSS_gp_err","SDSS_rp_err","SDSS_ip_err","SDSS_zp_err",
]

# define h5 file column description
h5_columns = define_column_desc(
    magnitude_column_names=magnitude_column_names, 
    id_name_length=25, 
)

# %%
h5_columns
# Out:
# {'id_name': StringCol(itemsize=25, shape=(), dflt=np.bytes_(b''), pos=0),
#  'ra': Float32Col(shape=(), dflt=np.float32(0.0), pos=1),
#  'ra_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=2),
#  'dec': Float32Col(shape=(), dflt=np.float32(0.0), pos=3),
#  'dec_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=4),
#  'SDSS_up': Float32Col(shape=(), dflt=np.float32(0.0), pos=5),
#  'SDSS_gp': Float32Col(shape=(), dflt=np.float32(0.0), pos=6),
#  'SDSS_rp': Float32Col(shape=(), dflt=np.float32(0.0), pos=7),
#  'SDSS_ip': Float32Col(shape=(), dflt=np.float32(0.0), pos=8),
#  'SDSS_zp': Float32Col(shape=(), dflt=np.float32(0.0), pos=9),
#  'SDSS_up_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=10),
#  'SDSS_gp_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=11),
#  'SDSS_rp_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=12),
#  'SDSS_ip_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=13),
#  'SDSS_zp_err': Float32Col(shape=(), dflt=np.float32(0.0), pos=14),
#  'ipix': Int32Col(shape=(), dflt=np.int32(0), pos=15),
#  'bucket': Int32Col(shape=(), dflt=np.int32(0), pos=16)}

# %% [markdown]
# # Read the cvs files

# %%
# file path
root_dir = Path("Southern_ugriz_processed")
files = list(root_dir.glob("*csv"))
files
# Out:
# [PosixPath('Southern_ugriz_processed/220000-595900_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E4_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/GD_108_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E3_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/000000-295830_processed.csv'),
#  PosixPath('Southern_ugriz_processed/MCT_2019_processed.csv'),
#  PosixPath('Southern_ugriz_processed/WD_0830-535_processed.csv'),
#  PosixPath('Southern_ugriz_processed/160100-600000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/075944-595500_processed.csv'),
#  PosixPath('Southern_ugriz_processed/080000-300000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/120000-600000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E5_b_processed.csv'),
#  PosixPath('Southern_ugriz_processed/120000-295355_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E2_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/140_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/040004-295900_processed.csv'),
#  PosixPath('Southern_ugriz_processed/NGC_458-AB_processed.csv'),
#  PosixPath('Southern_ugriz_processed/000000-600000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/200000-300000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/TPhe-B_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E5_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/132_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/160100-300000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/JL_163_processed.csv'),
#  PosixPath('Southern_ugriz_processed/055950-595600_processed.csv'),
#  PosixPath('Southern_ugriz_processed/040020-600200_processed.csv'),
#  PosixPath('Southern_ugriz_processed/180000-600000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/020020-600000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E8_b_processed.csv'),
#  PosixPath('Southern_ugriz_processed/140000-600000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/100000-600000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/CDFS_processed.csv'),
#  PosixPath('Southern_ugriz_processed/190000-295600_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E8_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/LSE_259_processed.csv'),
#  PosixPath('Southern_ugriz_processed/DLS_1052-05_processed.csv'),
#  PosixPath('Southern_ugriz_processed/195940-595000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/020000-300600_processed.csv'),
#  PosixPath('Southern_ugriz_processed/PG0942-029_processed.csv'),
#  PosixPath('Southern_ugriz_processed/DLS_1359-11_processed.csv'),
#  PosixPath('Southern_ugriz_processed/IC_2944-AB_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E9_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/220100-300000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/NGC_1841_processed.csv'),
#  PosixPath('Southern_ugriz_processed/PG1633+099_processed.csv'),
#  PosixPath('Southern_ugriz_processed/WD_1056-384_processed.csv'),
#  PosixPath('Southern_ugriz_processed/LSE_44_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E1_b_processed.csv'),
#  PosixPath('Southern_ugriz_processed/100000-300000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/140000-300000_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E6_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/DLS_0520-49_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E1_a_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E6_b_processed.csv'),
#  PosixPath('Southern_ugriz_processed/JL_82_processed.csv'),
#  PosixPath('Southern_ugriz_processed/E9_b_processed.csv'),
#  PosixPath('Southern_ugriz_processed/NGC_300-A_processed.csv'),
#  PosixPath('Southern_ugriz_processed/060000-300000_processed.csv')]

# %%
# csv column names
colnames = [
    "id_name", "ra", "dec",
    "SDSS_up", "SDSS_gp","SDSS_rp", "SDSS_ip","SDSS_zp",
    "SDSS_up_err", "SDSS_gp_err", "SDSS_rp_err", "SDSS_ip_err", "SDSS_zp_err",
]

dataframe_iterator = iter_multi_csv_chunks(
    files=files, 
    chunksize=10, 
    read_csv_kwargs={
        "sep": ",", 
        "engine": "python", 
        "header":0,
    }
)

# %%
table_attrs = {
    "source": "https://www-star.fnal.gov/Southern_ugriz/New/index.html",
    "ra_unit": "deg",
    "dec_unit": "deg",
    "ra_err_unit": "arcsec",
    "dec_err_unit": "arcsec",
    "version": "10 September 2012",
    "mag_system": {
        "SDSS_ugriz": "AB",
    },
}

# %%
write_std_h5(
    dataframe_iterator=dataframe_iterator, 
    ra_dec_hmsdms=True,
    h5_output_path=Path("Smith_Southern_Sky.h5",), 
    group_where="/smith", 
    group_name="southern", 
    group_title="Southern Sky", 
    table_name="std", 
    table_description=h5_columns, 
    table_title="Standard Stars", 
    table_attrs=table_attrs, 
    nside=512, 
    bucket_size=1536 , 
)
# Out:
# Files:   0%|          | 0/58 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/5 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/4 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/5 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/22 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/16 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/8 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/18 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/35 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/11 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/3 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/5 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/3 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/5 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/4 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/3 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/8 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/22 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/31 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/12 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/6 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/13 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/4 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/44 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/2 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/6 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/11 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/5 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/4 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/3 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/3 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                            | 0/12 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/4 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
# Chunks:   0%|                                             | 0/5 [00:00<?, ?it/s]
