# %%
from plot_spec_file import SpecResults
from pathlib import Path

# %%
file_path = Path("./Id019402431_QSO.spec").resolve()
file_path = Path("./Id019402431_GAL.spec").resolve()

spec = SpecResults(file_path)
spec.plot_results(save_path = file_path.parent / f"{file_path.stem}.png")
