# %%
from compile_apass import build_apass_h5
from pathlib import Path

# %%
file_list = [Path("./zm90.txt"), 
             Path("./zp85.txt"), 
            ]

# %%
build_apass_h5(
    text_path = file_list, 
    h5_path = Path("./test.h5"), 
    nside = 512, 
    bucket_size = 1536,
    chunksize = 1_000_000, 
)
# Out:
# ...
# chunks:   0%|                                             | 0/1 [00:00<?, ?it/s]
